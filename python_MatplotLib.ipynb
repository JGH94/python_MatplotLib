# %% [markdown]
# <a href="https://colab.research.google.com/github/JGH94/python_MatplotLib/blob/main/python_MatplotLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
# 기초 사용법 
print("1. 기초 사용법")
plt.plot([1, 2, 3, 4]) # plt 리스트 하나일 경우 y로 인식, X값은 자동으로 생성
plt.show() 

# 라인 및 점선 표현
# plt 리스트가 2개는 첫번째 인자는 X, 두번째 인자가 Y 값을 표현
print("2. 라인 및 점선 표현")
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'b-') # x좌표에  1, 4, 9 , 16을 표현 , b- 는 blue(파랑)의 -라인을 의미
plt.axis([0, 6, 0, 20])
plt.show()

plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro') # x좌표에  1, 4, 9 , 16을 표현 , ro는 빨간색 (‘red’)의 원형 (‘o’) 마커를 의미
plt.axis([0, 6, 0, 20])
plt.show()

# 여러 개의 표현
print("3. 여러개의 표현")
num_ = np.arange(0., 5., 0.2)
plt.plot(num_, num_, 'r--', num_, num_**2, 'bs', num_, num_**3, 'g^')
plt.show()
# Out:
# 1. 기초 사용법
# 2. 라인 및 점선 표현
# 3. 여러개의 표현

# %%
# 레이블의 표현
print("1. 레이블 표현")
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X_Lable', labelpad=15)
plt.ylabel('Y_Lable', labelpad=15)
plt.show()

# 레이블 폰트 설정
print("2. 레이블 폰트 설정 및 범례표시")
# 범례를 위한 lable
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Count')
font1 = {'family': 'serif',
         'color': 'red',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'deeppink',
         'weight': 'normal',
         'size': 'xx-large'
         }
plt.xlabel('X_Lable', labelpad=15, fontdict = font1)
plt.ylabel('Y_Lable', labelpad=15, fontdict = font2)
# 범례 표시 loc = 위치 설정
plt.legend(loc ='lower right')
plt.show()
# Out:
# 1. 레이블 표현
# 2. 레이블 폰트 설정 및 범례표시

# %%
 # 여러 데이터 표현 
print("1. 여러 데이터 표현 ")
# 범례를 위한 lable
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Count')
plt.plot([1, 2, 3, 4], [5, 1, 4, 12], label='Price')

font1 = {'family': 'serif',
         'color': 'black',
         'weight': 'bold',
         'size': 10
         }
 
plt.xlabel('X_Lable', labelpad=5, fontdict = font1)
plt.ylabel('Y_Lable', labelpad=5, fontdict = font1)
# 범례 표시 loc = 위치 설정
# nCol = 컬럼 개수 , fontsize 로 크기 조절 가능, frameon 로 테두리 설정(True or False), shadow 그림자 표시 (True or False)
plt.legend(loc ='lower right' , ncol = 2)
plt.show()
# Out:
# 1. 여러 데이터 표현
